# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Spotify_Youtuben.csv')

# %%
df
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20718  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20719  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20720  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20721  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20722  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
df = df.drop(columns = ['Url_spotify','Uri','Key','Url_youtube','Description'],axis = 1)

# %%
df.head(5)
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type  Danceability  \
# 0                                     Demon Days      album         0.818
# 1                                  Plastic Beach      album         0.676
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                  Plastic Beach      album         0.689
# 4                                       Gorillaz      album         0.663
#
#    Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0   0.705    -6.679       0.1770      0.008360          0.002330  ...
# ...

# %%
df.tail()
# Out:
#             Artist                           Track  \
# 20718  SICK LEGEND            JUST DANCE HARDSTYLE
# 20719  SICK LEGEND  SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND       OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND             ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND              MISS YOU HARDSTYLE
#
#                                 Album Album_type  Danceability  Energy  \
# 20718            JUST DANCE HARDSTYLE     single         0.582   0.926
# 20719  SET FIRE TO THE RAIN HARDSTYLE     single         0.531   0.936
# 20720       OUTSIDE HARDSTYLE SPED UP     single         0.443   0.830
# 20721             ONLY GIRL HARDSTYLE     single         0.417   0.767
# 20722              MISS YOU HARDSTYLE     single         0.498   0.938
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  ...    Tempo  \
# 20718    -6.344       0.0328       0.44800            0.0000  ...   90.002
# 20719    -1.786       0.1370       0.02800            0.0000  ...  174.869
# ...

# %%
df.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          2
# Energy                2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Licensed            470
# official_video      470
# Stream              577
# dtype: int64

# %%
df.describe()
# Out:
#        Danceability        Energy      Loudness   Speechiness  Acousticness  \
# count  20721.000000  20721.000000  20721.000000  20721.000000  20721.000000
# mean       0.619792      0.635245     -7.671438      0.096491      0.291497
# std        0.165268      0.214133      4.632751      0.112037      0.286277
# min        0.000000      0.000020    -46.251000      0.000000      0.000001
# 25%        0.519000      0.507000     -8.858000      0.035700      0.045200
# 50%        0.637000      0.666000     -6.536000      0.050500      0.193000
# 75%        0.741000      0.798000     -4.931000      0.103000      0.477000
# max        0.975000      1.000000      0.920000      0.964000      0.996000
#
#        Instrumentalness      Liveness       Valence         Tempo  \
# count      20721.000000  20721.000000  20721.000000  20721.000000
# mean           0.055948      0.193516      0.529853    120.638509
# std            0.193241      0.168529      0.245429     29.580004
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20723 entries, 0 to 20722
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20723 non-null  object
#  1   Track             20723 non-null  object
#  2   Album             20723 non-null  object
#  3   Album_type        20723 non-null  object
#  4   Danceability      20721 non-null  float64
#  5   Energy            20721 non-null  float64
#  6   Loudness          20721 non-null  float64
#  7   Speechiness       20721 non-null  float64
#  8   Acousticness      20721 non-null  float64
#  9   Instrumentalness  20721 non-null  float64
#  10  Liveness          20721 non-null  float64
#  11  Valence           20721 non-null  float64
#  12  Tempo             20721 non-null  float64
#  13  Duration_ms       20721 non-null  float64
#  14  Title             20253 non-null  object
#  15  Channel           20253 non-null  object
# ...

# %%
df = df.fillna(0)

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
df['Duration_ms']= df['Duration_ms']/(60000)

# %%
df.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Loudness  Speechiness  Acousticness  Instrumentalness  ...    Tempo  \
# 0    -6.679       0.1770       0.00836          0.002330  ...  138.559
# 1    -5.815       0.0302       0.08690          0.000687  ...   92.761
#
#    Duration_ms                                              Title   Channel  \
# 0     3.710667         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz
# 1     3.336217  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz
#
#          Views      Likes  Comments  Licensed  official_video        Stream
# 0  693555221.0  6220896.0  169907.0      True            True  1.040235e+09
# 1   72011645.0  1079128.0   31003.0      True            True  3.100837e+08
#
# [2 rows x 22 columns]

# %%
df.rename(columns={"Duration_ms":"Duration_min"},inplace= True)

# %%
df = df[~df["Track"].str.startswith("?")]

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
df["EnergyLiveness"] = df["Energy"]/df["Liveness"]

# %%
df["most_playedon"] = np.where(df["Stream"]>df["Views"],"Spotify","Youtube")

# %%
df.to_csv("cleaned_dataset.csv")

# %%
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20718  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20719  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20720  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20721  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20722  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...
